# %%
print("=============| Program Pemesan Otomatis Menu Sarapan Pagi Mc'Donalds |=============")
pembeli = input("Masukkan Nama Pembeli : ")
loop = True
while loop:
  total=0
  jenis=""
  sarapan=0
  porsi=0

  def fungsi_sarapan_pagi():
      global total
      global sarapan
      global jenis1
      print ("\n============================================================")
      print ("Pilihan Menu Sarapan Pagi Mc'Donalds")
      print ("1. Chicken Muffin with Egg - Rp.25000")
      print ("2. Sausage McMuffin with Egg - Rp.28636")
      print ("3. Sausage Wrap - Rp.25000")
      print ("4. Big Breakfast - Rp.31363")
      print ("5. Breakfast Wrap - Rp.26818")
      print ("6. Hotcakes 3 pcs - Rp.26363")
      print ("7. Hotcakes 2 pcs - Rp.21363")
      print ("8. Hasbrown - Rp.7727")
      print ("9. Nasi Uduk McD - Rp.18500")
      print ("10. Bubur Ayam McD - Rp.11500")
      print ("==============================================================")
      nomor = int(input("Masukan Pilihan :"))
      sarapan = int(input("Jumlah Pesanan Sarapan Pagi :"))
      if nomor==1:
          total=sarapan*25000
          print (sarapan,"Chicken Muffin with Egg = Rp", total)
          jenis=("Chicken Muffin with Egg")
      elif nomor==2:
          total=sarapan*28636
          print (sarapan,"Sausage McMuffin with Egg = Rp", total)
          jenis=("Sausage McMuffin with Egg")
      elif nomor==3:
          total=sarapan*25000
          print (sarapan,"Sausage Wrap = Rp", total)
          jenis=("Sausage Wrap")
      elif nomor==4:
          total=sarapan*31363
          print (sarapan,"Big Breakfast = Rp", total)
          jenis=("Big Breakfast")
      elif nomor==5:
          total=sarapan*26818
          print (sarapan,"Breakfast Wrap = Rp", total)
          jenis=("Breakfast Wrap")
      elif nomor==6:
          total=sarapan*26363
          print (sarapan,"Hotcakes 3 pcs = Rp", total)
          jenis=("Hotcakes 3 pcs")
      elif nomor==7:
          total=sarapan*21363
          print (sarapan, "Hotcakes 2 pcs= Rp", total)
          jenis=("Hotcakes 2 pcs")
      elif nomor==8:
          total=sarapan*7727
          print (sarapan, "Hasbrown = Rp", total)
          jenis=("Hasbrown")
      elif nomor==9:
          total=sarapan*18500
          print (sarapan, "Nasi Uduk McD = Rp", total)
          jenis=("Nasi Uduk McD")
      elif nomor==10:
          total=sarapan*11500
          print (sarapan, "Bubur Ayam McD = Rp", total)
          jenis=("Bubur Ayam McD")
      else:
          print ("Pilihan Menu Sarapan Tidak Tersedia, Silahkan Masukkan Pilihan Lagi!")
          fungsi_sarapan_pagi()
  fungsi_sarapan_pagi()

  totalsemua=total
  print ("==============================================================")
  print ("Nama Pembeli : ", pembeli)
  print ("Total Sarapan Pagi Harus Dibayar : Rp.", totalsemua)
  def pesanan():
      uang = int(input("Uang Tunai Pembeli : Rp."))
      if uang==totalsemua:
          kembalian = int(uang - totalsemua)
          print ("Kembalian : Rp.", kembalian)
          print ("==============Terimakasih Selamat Datang Kembali==============")
      elif uang>=totalsemua:
          kembalian = int(uang - totalsemua)
          print ("Kembalian : Rp.", kembalian)
          print ("==============Terimakasih Selamat Datang Kembali==============")
      else:
          print ("============================================================")
          print ("!!! Maaf Uang Anda Tidak Cukup, Silahkan Bayar Kembali !!!")
          print ("============================================================")
          pesanan()
  pesanan()
